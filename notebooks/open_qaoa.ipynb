# %%
import networkx
from openqaoa.problems import MinimumVertexCover

g = networkx.circulant_graph(6, [1])
vc = MinimumVertexCover(g, field=1.0, penalty=10)
qubo_problem = vc.qubo
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~/conda/envs/myenv/lib/python3.10/site-packages/azure/quantum/qiskit/backends/backend.py:29
#      28 from qiskit.providers.models import BackendConfiguration
# ---> 29 from qiskit.qobj import Qobj, QasmQobj
#      30 from pyqir import Module
#
# ImportError: cannot import name 'Qobj' from 'qiskit.qobj' (/home/ziqguo/conda/envs/myenv/lib/python3.10/site-packages/qiskit/qobj/__init__.py)
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 2
#       1 import networkx
# ----> 2 from openqaoa.problems import MinimumVertexCover
#       4 g = networkx.circulant_graph(6, [1])
#       5 vc = MinimumVertexCover(g, field=1.0, penalty=10)
#
# File ~/conda/envs/myenv/lib/python3.10/site-packages/openqaoa/__init__.py:1
# ----> 1 from .algorithms import QAOA, RQAOA, QAOABenchmark
#       2 from .problems import QUBO
#       3 from .backends import create_device
#
# File ~/conda/envs/myenv/lib/python3.10/site-packages/openqaoa/algorithms/__init__.py:1
# ----> 1 from .qaoa import QAOA, QAOAResult, QAOABenchmark
#       2 from .rqaoa import RQAOA, RQAOAResult
#
# File ~/conda/envs/myenv/lib/python3.10/site-packages/openqaoa/algorithms/qaoa/__init__.py:1
# ----> 1 from .qaoa_workflow import QAOA
#       2 from .qaoa_result import QAOAResult
#       3 from .qaoa_benchmark import QAOABenchmark
#
# File ~/conda/envs/myenv/lib/python3.10/site-packages/openqaoa/algorithms/qaoa/qaoa_workflow.py:5
#       2 from copy import deepcopy
#       3 import numpy as np
# ----> 5 from .qaoa_result import QAOAResult
#       6 from ..workflow_properties import CircuitProperties
#       7 from ..baseworkflow import Workflow, check_compiled
#
# File ~/conda/envs/myenv/lib/python3.10/site-packages/openqaoa/algorithms/qaoa/qaoa_result.py:18
#      11     from ...optimizers.logger_vqa import Logger
#      12 from ...utilities import (
#      13     qaoa_probabilities,
#      14     bitstring_energy,
#      15     convert2serialize,
#      16     delete_keys_from_dict,
#      17 )
# ---> 18 from ...backends.basebackend import QAOABaseBackend, QAOABaseBackendStatevector
#      19 from ...backends.qaoa_analytical_sim import QAOABackendAnalyticalSimulator
#      22 def most_probable_bitstring(cost_hamiltonian, measurement_outcomes):
#
# File ~/conda/envs/myenv/lib/python3.10/site-packages/openqaoa/backends/__init__.py:18
#      16 from .qaoa_vectorized import QAOAvectorizedBackendSimulator
#      17 from .qaoa_analytical_sim import QAOABackendAnalyticalSimulator
# ---> 18 from .devices_core import DeviceLocal
#      19 from .qaoa_device import create_device
#
# File ~/conda/envs/myenv/lib/python3.10/site-packages/openqaoa/backends/devices_core.py:5
#       2 import networkx as nx
#       4 from .basedevice import DeviceBase
# ----> 5 from .plugin_finder import PLUGIN_DICT
#       8 def obtain_support_simulators() -> list:
#       9     """This method returns a list containing the names of simulators supported
#      10     by OQ. This list varies depending on the plugins available.
#      11     """
#
# File ~/conda/envs/myenv/lib/python3.10/site-packages/openqaoa/backends/plugin_finder.py:58
#      36     return output_dict
#      39 #     output_dict = dict()
#      40
#      41 #     try:
#    (...)
#      55
#      56 #     return output_dict
# ---> 58 PLUGIN_DICT = plugin_finder_dict()
#
# File ~/conda/envs/myenv/lib/python3.10/site-packages/openqaoa/backends/plugin_finder.py:21, in plugin_finder_dict()
#      19 for each_plugin_entry_point in available_plugins:
#      20     try:
# ---> 21         output_dict[each_plugin_entry_point.name] = each_plugin_entry_point.load()
#      22     except ModuleNotFoundError as e:
#      23         print(
#      24             "The {} module has not been installed.".format(
#      25                 each_plugin_entry_point.name
#      26             )
#      27         )
#
# File ~/conda/envs/myenv/lib/python3.10/importlib/metadata/__init__.py:171, in EntryPoint.load(self)
#     166 """Load the entry point from its definition. If only a module
#     167 is indicated by the value, return that module. Otherwise,
#     168 return the named object.
#     169 """
#     170 match = self.pattern.match(self.value)
# --> 171 module = import_module(match.group('module'))
#     172 attrs = filter(None, (match.group('attr') or '').split('.'))
#     173 return functools.reduce(getattr, attrs, module)
#
# File ~/conda/envs/myenv/lib/python3.10/importlib/__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File ~/conda/envs/myenv/lib/python3.10/site-packages/openqaoa_azure/backend_config.py:1
# ----> 1 from .backends import DeviceAzure
#       3 from openqaoa_qiskit.backends import QAOAQiskitQPUBackend
#       5 device_access = {DeviceAzure: QAOAQiskitQPUBackend}
#
# File ~/conda/envs/myenv/lib/python3.10/site-packages/openqaoa_azure/backends/__init__.py:1
# ----> 1 from .devices import DeviceAzure
#
# File ~/conda/envs/myenv/lib/python3.10/site-packages/openqaoa_azure/backends/devices.py:3
#       1 from typing import List
# ----> 3 from azure.quantum.qiskit import AzureQuantumProvider
#       4 from openqaoa.backends.devices_core import DeviceBase
#       7 class DeviceAzure(DeviceBase):
#
# File ~/conda/envs/myenv/lib/python3.10/site-packages/azure/quantum/qiskit/__init__.py:8
#       1 ##
#       2 # Copyright (c) Microsoft Corporation.
#       3 # Licensed under the MIT License.
#       4 ##
#       6 """Azure Quantum Qiskit Provider"""
# ----> 8 from .provider import AzureQuantumProvider
#       9 from azure.quantum import __version__
#      11 __all__ = [
#      12     "AzureQuantumProvider",
#      13     "__version__"
#      14 ]
#
# File ~/conda/envs/myenv/lib/python3.10/site-packages/azure/quantum/qiskit/provider.py:20
#      18 from typing import Dict, List, Tuple, Type
#      19 from azure.quantum import Workspace
# ---> 20 from azure.quantum.qiskit.backends.backend import AzureBackendBase
#      21 from azure.quantum.qiskit.job import AzureQuantumJob
#      22 from azure.quantum.qiskit.backends import *
#
# File ~/conda/envs/myenv/lib/python3.10/site-packages/azure/quantum/qiskit/backends/__init__.py:6
#       1 ##
#       2 # Copyright (c) Microsoft Corporation.
#       3 # Licensed under the MIT License.
#       4 ##
# ----> 6 from azure.quantum.qiskit.backends.ionq import (
#       7     IonQBackend,
#       8     IonQQPUBackend,
#       9     IonQAriaBackend,
#      10     IonQSimulatorBackend,
#      11     IonQQPUQirBackend,
#      12     IonQAriaQirBackend,
#      13     IonQSimulatorQirBackend,
#      14 )
#      16 from azure.quantum.qiskit.backends.quantinuum import (
#      17     QuantinuumBackend,
#      18     QuantinuumQPUBackend,
#    (...)
#      23     QuantinuumEmulatorQirBackend,
#      24 )
#      26 from azure.quantum.qiskit.backends.rigetti import (
#      27     RigettiBackend,
#      28     RigettiQPUBackend,
#      29     RigettiSimulatorBackend,
#      30 )
#
# File ~/conda/envs/myenv/lib/python3.10/site-packages/azure/quantum/qiskit/backends/ionq.py:10
#       7 from azure.quantum.target.ionq import IonQ
#       8 from abc import abstractmethod
# ---> 10 from .backend import AzureBackend, AzureQirBackend
#      12 from qiskit.providers.models import BackendConfiguration
#      13 from qiskit.providers import Options, Provider
#
# File ~/conda/envs/myenv/lib/python3.10/site-packages/azure/quantum/qiskit/backends/backend.py:34
#      31     from qiskit_qir import to_qir_module
#      33 except ImportError:
# ---> 34     raise ImportError(
#      35         "Missing optional 'qiskit' dependencies. \
#      36 To install run: pip install azure-quantum[qiskit]"
#      37     )
#      40 class AzureBackendBase(Backend, SessionHost):
#      41     @abstractmethod
#      42     def __init__(
#      43         self,
#    (...)
#      46         **fields
#      47     ):
#
# ImportError: Missing optional 'qiskit' dependencies. To install run: pip install azure-quantum[qiskit]

# %%
from openqaoa import QAOA  

q = QAOA()
q.compile(qubo_problem)
q.optimize()
# Out:
# The kernel failed to start as 'cd_completer' could not be imported from '/home/ziqguo/conda/envs/myenv/lib/python3.10/site-packages/IPython/core/completerlib.py'.
#
# Click <a href='https://aka.ms/kernelFailuresModuleImportErrFromFile'>here</a> for more info.
